# %% [markdown]
# ## Getting Satellite Images

# %%
import csv
import os
import requests

# Mapbox access token
access_token = 'pk.eyJ1IjoicHdpbGxpYW1zcGVuaWVsIiwiYSI6ImNseTVlaDY5NDA2ajQyanNibTJ0NzRlaHEifQ.CIy2ghSbnbxjZObgNqyMqQ'

# Path to CSV file
csv_file_path = '/content/drive/MyDrive/Autoencoders/demo_tract.csv'

# Image path folder
output_folder = '/content/drive/MyDrive/Autoencoders/data_directory/satellite_images'

#Parameters for the Mapbox Static Images API
mapbox_api_url = 'https://api.mapbox.com/styles/v1/mapbox/satellite-v9/static'
image_size = '256x256'
zoom_level = 15
bearing = 0

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Open the CSV file and read the coordinates
with open(csv_file_path, mode='r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:

        latitude = row['INTPTLAT']
        longitude = row['INTPTLON']

        # Construct the API URL with the coordinates
        api_url = f'{mapbox_api_url}/{longitude},{latitude},{zoom_level},{bearing}/{image_size}?access_token={access_token}'

        # Make the request to the Mapbox API
        response = requests.get(api_url)

        # Check if the request was successful
        if response.status_code == 200:
            # Define the output image path
            image_path = os.path.join(output_folder, f'image_{longitude}_{latitude}.png')

            # Save the image to the output folder
            with open(image_path, 'wb') as image_file:
                image_file.write(response.content)
            print(f'Image saved for coordinates {longitude}, {latitude}')
        else:
            print(f'Failed to retrieve image for coordinates {longitude}, {latitude}')
# Out:
# Image saved for coordinates -102.5331983, +46.0968146
# Image saved for coordinates -097.8551057, +46.9370110
# Image saved for coordinates -098.2386037, +46.9379265
# Image saved for coordinates -098.0215419, +46.9195583
# Image saved for coordinates -097.9842832, +46.9299130
# Image saved for coordinates -099.1577586, +47.9418196
# Image saved for coordinates -098.7589395, +47.9268862
# Image saved for coordinates -099.5357163, +48.1305920
# Image saved for coordinates -103.3640163, +47.0070440
# Image saved for coordinates -100.4460399, +48.8206477
# Image saved for coordinates -100.5257167, +48.8022043
# Image saved for coordinates -101.2015486, +48.7703061
# Image saved for coordinates -103.3943289, +46.2009980
# Image saved for coordinates -103.5059433, +46.1101438
# Image saved for coordinates -102.5200874, +48.7864534
# Image saved for coordinates -100.7866265, +46.8089077
# Image saved for coordinates -100.7645331, +46.8107113
# Image saved for coordinates -100.7641087, +46.8235691
# Image saved for coordinates -100.7841820, +46.8242771
# Image saved for coordinates -100.8067416, +46.8180735
# Image saved for coordinates -100.8095987, +46.7832969
# Image saved for coordinates -100.7866428, +46.7910633
# Image saved for coordinates -100.7662942, +46.7948726
# Image saved for coordinates -100.7417005, +46.8158238
# Image saved for coordinates -100.7514734, +46.8563148
# Image saved for coordinates -100.7191564, +46.9202764
# Image saved for coordinates -100.7832331, +46.8419458
# Image saved for coordinates -100.8165618, +46.8316386
# Image saved for coordinates -100.8182944, +46.8517070
# Image saved for coordinates -100.8473940, +46.9223176
# Image saved for coordinates -100.7536162, +46.7220607
# Image saved for coordinates -100.6986812, +46.7633703
# Image saved for coordinates -100.3712269, +46.8160787
# Image saved for coordinates -100.4849319, +47.1495161
# Image saved for coordinates -096.7713752, +46.9135947
# Image saved for coordinates -096.7829553, +46.9177876
# Image saved for coordinates -096.7926911, +46.9185680
# Image saved for coordinates -096.8236083, +46.9307423
# Image saved for coordinates -096.7900678, +46.8964147
# Image saved for coordinates -096.7817544, +46.8849968
# Image saved for coordinates -096.8020666, +46.8871525
# Image saved for coordinates -096.8288868, +46.8779273
# Image saved for coordinates -096.8080840, +46.8772785
# Image saved for coordinates -096.7862040, +46.8770696
# Image saved for coordinates -096.7901178, +46.8677209
# Image saved for coordinates -096.8078779, +46.8667398
# Image saved for coordinates -096.7940048, +46.8547291
# Image saved for coordinates -096.8303060, +46.8579460
# Image saved for coordinates -096.8224448, +46.8526054
# Image saved for coordinates -096.8122260, +46.8414922
# Image saved for coordinates -096.7946863, +46.8401518
# Image saved for coordinates -096.8515597, +46.8569085
# Image saved for coordinates -096.8599091, +46.8862260
# Image saved for coordinates -096.8723391, +46.8692552
# Image saved for coordinates -096.8777931, +46.8548175
# Image saved for coordinates -096.8671927, +46.8547314
# Image saved for coordinates -096.9281614, +46.8730258
# Image saved for coordinates -096.8929797, +46.8541610
# Image saved for coordinates -096.8947270, +46.8715777
# Image saved for coordinates -096.8294391, +46.8181909
# Image saved for coordinates -096.8035933, +46.8278500
# Image saved for coordinates -096.8092603, +46.8131871
# Image saved for coordinates -096.8303191, +46.8400349
# Image saved for coordinates -097.5440469, +46.9103940
# Image saved for coordinates -097.1444195, +47.1297474
# Image saved for coordinates -097.2311175, +46.9268811
# Image saved for coordinates -096.8703804, +46.8208064
# Image saved for coordinates -096.9139870, +46.8363823
# Image saved for coordinates -096.9052836, +46.7551572
# Image saved for coordinates -096.8505911, +46.8183346
# Image saved for coordinates -096.8179498, +46.7962729
# Image saved for coordinates -096.8844370, +46.8118725
# Image saved for coordinates -096.9131694, +46.8081584
# Image saved for coordinates -096.8915269, +46.8337908
# Image saved for coordinates -096.8292195, +46.7565760
# Image saved for coordinates -097.0848879, +46.7120804
# Image saved for coordinates -096.8620330, +46.8401089
# Image saved for coordinates -096.9687212, +46.9314840
# Image saved for coordinates -098.3770270, +48.7617270
# Image saved for coordinates -098.4637903, +48.7684388
# Image saved for coordinates -098.0935845, +46.1196728
# Image saved for coordinates -098.5755238, +46.1083792
# Image saved for coordinates -098.5159328, +46.0051385
# Image saved for coordinates -103.5093256, +48.8147537
# Image saved for coordinates -102.6123216, +47.3545572
# Image saved for coordinates -098.9004745, +47.7234355
# Image saved for coordinates -100.2378424, +46.2842552
# Image saved for coordinates -098.8728755, +47.4714315
# Image saved for coordinates -103.8446117, +46.9389237
# Image saved for coordinates -097.0412314, +47.9293043
# Image saved for coordinates -097.0555688, +47.9260119
# Image saved for coordinates -097.0699331, +47.9249984
# Image saved for coordinates -097.0817655, +47.9217085
# Image saved for coordinates -097.1047087, +47.9262245
# Image saved for coordinates -097.0278242, +47.9189705
# Image saved for coordinates -097.0503268, +47.9112492
# Image saved for coordinates -097.0836560, +47.9104222
# Image saved for coordinates -097.0865703, +47.8975470
# Image saved for coordinates -097.0612410, +47.8967008
# Image saved for coordinates -097.0504632, +47.8966748
# Image saved for coordinates -097.0255125, +47.9021028
# Image saved for coordinates -097.0403561, +47.9113650
# Image saved for coordinates -097.0262277, +47.8740261
# Image saved for coordinates -097.0404716, +47.8949095
# Image saved for coordinates -097.0540222, +47.8756451
# Image saved for coordinates -097.4597587, +48.1003897
# Image saved for coordinates -097.2070522, +47.9258331
# Image saved for coordinates -097.1449361, +47.7612548
# Image saved for coordinates -097.6334558, +47.7659949
# Image saved for coordinates -097.3912796, +47.9556796
# Image saved for coordinates -097.6545610, +47.9438011
# Image saved for coordinates -101.6390494, +46.3578269
# Image saved for coordinates -098.2322863, +47.4563342
# Image saved for coordinates -102.2257352, +46.4064976
# Image saved for coordinates -102.6674440, +46.4620206
# Image saved for coordinates -099.7869096, +47.0990090
# Image saved for coordinates -098.1911064, +46.4495529
# Image saved for coordinates -098.6790608, +46.4640230
# Image saved for coordinates -099.5045846, +46.4692780
# Image saved for coordinates -100.6444523, +48.3880609
# Image saved for coordinates -100.6174187, +48.0147679
# Image saved for coordinates -099.4164868, +46.1086815
# Image saved for coordinates -102.7054702, +47.8457348
# Image saved for coordinates -103.0792963, +47.9253675
# Image saved for coordinates -103.3457723, +47.5441221
# Image saved for coordinates -103.2632769, +47.8014116
# Image saved for coordinates -103.7871557, +47.6892314
# Image saved for coordinates -102.0360125, +47.6964776
# Image saved for coordinates -101.0418417, +47.3804368
# Image saved for coordinates -101.1982034, +47.7039240
# Image saved for coordinates -101.6296381, +47.3160214
# Image saved for coordinates -101.7945263, +47.2781568
# Image saved for coordinates -101.8333279, +47.3071473
# Image saved for coordinates -100.8855955, +46.8314192
# Image saved for coordinates -100.9511068, +46.9024702
# Image saved for coordinates -100.8528649, +46.7901560
# Image saved for coordinates -100.8851984, +46.7908202
# Image saved for coordinates -100.9402161, +46.7935061
# Image saved for coordinates -100.9974910, +46.6253142
# Image saved for coordinates -101.6839614, +46.8312496
# Image saved for coordinates -102.0762006, +47.9269275
# Image saved for coordinates -102.4662993, +47.8874140
# Image saved for coordinates -102.3859844, +48.2764978
# Image saved for coordinates -098.2044278, +47.9186666
# Image saved for coordinates -101.3314198, +47.1180789
# Image saved for coordinates -097.3604670, +48.8946419
# Image saved for coordinates -097.7419482, +48.9131222
# Image saved for coordinates -097.3532387, +48.6662851
# Image saved for coordinates -097.7450080, +48.6799737
# Image saved for coordinates -099.8739187, +48.4797921
# Image saved for coordinates -100.0315558, +48.1159478
# Image saved for coordinates -098.8393598, +48.0989362
# Image saved for coordinates -098.7390310, +48.2661631
# Image saved for coordinates -098.8987130, +48.0750508
# Image saved for coordinates -097.4199237, +46.4797221
# Image saved for coordinates -097.7939289, +46.4517152
# Image saved for coordinates -097.6811628, +46.4348949
# Image saved for coordinates -101.6581522, +48.7127815
# Image saved for coordinates -097.0003129, +46.5360026
# Image saved for coordinates -096.9761797, +46.3483366
# Image saved for coordinates -096.6169617, +46.3057623
# Image saved for coordinates -096.6067392, +46.2560922
# Image saved for coordinates -096.7047120, +46.0907757
# Image saved for coordinates -097.0422982, +46.0951712
# Image saved for coordinates -099.7943891, +48.8622578
# Image saved for coordinates -099.5872508, +48.9046100
# Image saved for coordinates -099.9582925, +48.9102598
# Image saved for coordinates -099.8289101, +48.6693037
# Image saved for coordinates -097.7676122, +46.1889713
# Image saved for coordinates -097.5504114, +46.0681103
# Image saved for coordinates -100.3309858, +47.5813594
# Image saved for coordinates -101.1512654, +46.1260283
# Image saved for coordinates -100.6980165, +46.0854696
# Image saved for coordinates -103.4624620, +46.4458338
# Image saved for coordinates -102.3052131, +46.8105712
# Image saved for coordinates -102.7659068, +46.9066147
# Image saved for coordinates -102.8126405, +46.8865433
# Image saved for coordinates -102.8157086, +46.9138395
# Image saved for coordinates -102.7993256, +46.8825432
# Image saved for coordinates -102.7790004, +46.8841310
# Image saved for coordinates -102.7734334, +46.8568605
# Image saved for coordinates -102.7363668, +46.8141906
# Image saved for coordinates -103.0961791, +46.7917593
# Image saved for coordinates -097.7189200, +47.4510624
# Image saved for coordinates -098.9638091, +47.1286697
# Image saved for coordinates -098.9548437, +46.7703032
# Image saved for coordinates -098.6690059, +46.9155254
# Image saved for coordinates -098.6981303, +46.9166012
# Image saved for coordinates -098.7011508, +46.9275229
# Image saved for coordinates -098.7469079, +46.9135854
# Image saved for coordinates -098.7043901, +46.8931127
# Image saved for coordinates -099.2481583, +48.6821831
# Image saved for coordinates -097.1668254, +47.5923190
# Image saved for coordinates -097.3463906, +47.4976781
# Image saved for coordinates -097.1713933, +47.3689668
# Image saved for coordinates -097.0448312, +47.4121339
# Image saved for coordinates -097.2886672, +48.3610643
# Image saved for coordinates -097.3888961, +48.4204239
# Image saved for coordinates -097.4270009, +48.4216884
# Image saved for coordinates -097.6329732, +48.3617235
# Image saved for coordinates -097.7520584, +48.3962706
# Image saved for coordinates -098.0900073, +48.3840185
# Image saved for coordinates -101.2911967, +48.2316853
# Image saved for coordinates -101.2656958, +48.2540499
# Image saved for coordinates -101.3100418, +48.2668701
# Image saved for coordinates -101.3247672, +48.2498331
# Image saved for coordinates -101.3149561, +48.2393084
# Image saved for coordinates -101.3165800, +48.2221056
# Image saved for coordinates -101.3215807, +48.2050068
# Image saved for coordinates -101.2503187, +48.2042409
# Image saved for coordinates -101.2767783, +48.2177595
# Image saved for coordinates -101.2499540, +48.2241770
# Image saved for coordinates -101.2633211, +48.3565295
# Image saved for coordinates -101.3260868, +48.4280300
# Image saved for coordinates -101.3365027, +48.4190017
# Image saved for coordinates -101.9011570, +48.5329294
# Image saved for coordinates -101.1339731, +48.0301137
# Image saved for coordinates -101.5992092, +48.0811576
# Image saved for coordinates -099.9205873, +47.7670446
# Image saved for coordinates -099.6822135, +47.5808513
# Image saved for coordinates -103.2641775, +48.4961603
# Image saved for coordinates -103.8535094, +48.3342050
# Image saved for coordinates -103.2485660, +48.2207248
# Image saved for coordinates -103.6418456, +48.2090666
# Image saved for coordinates -103.6946317, +48.1446806
# Image saved for coordinates -103.6347758, +48.1599295
# Image saved for coordinates -103.6091103, +48.1588754
# Image saved for coordinates -103.6495275, +48.1362661

# %%
import cv2
import glob
import matplotlib.pyplot as plt
import numpy as np

# %%
image_list = glob.glob('/content/drive/MyDrive/Autoencoders/data_directory/satellite_images/*.png')

# %%
len(image_list)
# Out:
# 228

# %% [markdown]
# ### Crop

# %%
def center_crop(img, dim):
    """Returns center cropped image
    Args:
    img: image to be center cropped
    dim: dimensions (width, height) to be cropped
    """

    width, height = img.shape[1], img.shape[0]

    # process crop width and height for max available dimension
    crop_width = dim[0] if dim[0]<img.shape[1] else img.shape[1]
    crop_height = dim[1] if dim[1]<img.shape[0] else img.shape[0]
    mid_x, mid_y = int(width/2), int(height/2)
    cw2, ch2 = int(crop_width/2), int(crop_height/2)
    crop_img = img[mid_y-ch2:mid_y+ch2, mid_x-cw2:mid_x+cw2]
    return crop_img

# %%
# Directory to save processed images with '_64'
output_folder = '/content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Process each image in the list
for i in image_list:
    # Read the image
    im = cv2.imread(i)

    # Apply center crop and resize
    im = center_crop(im, (224, 224))
    im = cv2.resize(im, (64, 64))

    # Extract the file name from the path
    file_name = os.path.basename(i)

    # Create a new file name with '_64' attached
    new_name = os.path.join(output_folder, file_name.replace('.png', '_64.png'))

    # Save the processed image with the new name
    cv2.imwrite(new_name, im)

    print(f'Saved processed image as {new_name}')
# Out:
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-102.5331983_+46.0968146_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.8551057_+46.9370110_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-098.2386037_+46.9379265_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-098.0215419_+46.9195583_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.9842832_+46.9299130_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-099.1577586_+47.9418196_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-098.7589395_+47.9268862_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-099.5357163_+48.1305920_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-103.3640163_+47.0070440_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.4460399_+48.8206477_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.5257167_+48.8022043_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.2015486_+48.7703061_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-103.3943289_+46.2009980_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-103.5059433_+46.1101438_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-102.5200874_+48.7864534_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.7866265_+46.8089077_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.7645331_+46.8107113_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.7641087_+46.8235691_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.7841820_+46.8242771_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.8067416_+46.8180735_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.8095987_+46.7832969_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.7866428_+46.7910633_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.7662942_+46.7948726_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.7417005_+46.8158238_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.7514734_+46.8563148_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.7191564_+46.9202764_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.7832331_+46.8419458_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.8165618_+46.8316386_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.8182944_+46.8517070_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.8473940_+46.9223176_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.7536162_+46.7220607_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.6986812_+46.7633703_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.3712269_+46.8160787_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-100.4849319_+47.1495161_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.7713752_+46.9135947_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.7829553_+46.9177876_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.7926911_+46.9185680_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8236083_+46.9307423_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.7900678_+46.8964147_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.7817544_+46.8849968_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8020666_+46.8871525_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8288868_+46.8779273_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8080840_+46.8772785_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.7862040_+46.8770696_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.7901178_+46.8677209_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8078779_+46.8667398_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.7940048_+46.8547291_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8303060_+46.8579460_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8224448_+46.8526054_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8122260_+46.8414922_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.7946863_+46.8401518_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8515597_+46.8569085_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8599091_+46.8862260_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8723391_+46.8692552_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8777931_+46.8548175_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8671927_+46.8547314_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.9281614_+46.8730258_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8929797_+46.8541610_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8947270_+46.8715777_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8294391_+46.8181909_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8035933_+46.8278500_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8092603_+46.8131871_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-096.8303191_+46.8400349_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.5440469_+46.9103940_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.1444195_+47.1297474_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097
64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-102.8157086_+46.9138395_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-102.7993256_+46.8825432_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-102.7790004_+46.8841310_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-102.7734334_+46.8568605_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-102.7363668_+46.8141906_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-103.0961791_+46.7917593_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.7189200_+47.4510624_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-098.9638091_+47.1286697_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-098.9548437_+46.7703032_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-098.6690059_+46.9155254_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-098.6981303_+46.9166012_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-098.7011508_+46.9275229_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-098.7469079_+46.9135854_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-098.7043901_+46.8931127_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-099.2481583_+48.6821831_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.1668254_+47.5923190_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.3463906_+47.4976781_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.1713933_+47.3689668_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.0448312_+47.4121339_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.2886672_+48.3610643_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.3888961_+48.4204239_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.4270009_+48.4216884_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.6329732_+48.3617235_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-097.7520584_+48.3962706_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-098.0900073_+48.3840185_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.2911967_+48.2316853_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.2656958_+48.2540499_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.3100418_+48.2668701_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.3247672_+48.2498331_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.3149561_+48.2393084_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.3165800_+48.2221056_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.3215807_+48.2050068_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.2503187_+48.2042409_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.2767783_+48.2177595_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.2499540_+48.2241770_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.2633211_+48.3565295_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.3260868_+48.4280300_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.3365027_+48.4190017_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.9011570_+48.5329294_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.1339731_+48.0301137_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-101.5992092_+48.0811576_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-099.9205873_+47.7670446_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-099.6822135_+47.5808513_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-103.2641775_+48.4961603_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-103.8535094_+48.3342050_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-103.2485660_+48.2207248_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-103.6418456_+48.2090666_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-103.6946317_+48.1446806_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-103.6347758_+48.1599295_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-103.6091103_+48.1588754_64.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_64/image_-103.6495275_+48.1362661_64.png

# %%
len(image_list)
# Out:
# 228

# %% [markdown]
# ## Blur

# %%
image_list = glob.glob('/content/drive/MyDrive/Autoencoders/data_directory/satellite_images/*.png')

# %%
image_list[:5]
# Out:
# ['/content/drive/MyDrive/Autoencoders/data_directory/satellite_images/image_-102.5331983_+46.0968146.png',
#  '/content/drive/MyDrive/Autoencoders/data_directory/satellite_images/image_-097.8551057_+46.9370110.png',
#  '/content/drive/MyDrive/Autoencoders/data_directory/satellite_images/image_-098.2386037_+46.9379265.png',
#  '/content/drive/MyDrive/Autoencoders/data_directory/satellite_images/image_-098.0215419_+46.9195583.png',
#  '/content/drive/MyDrive/Autoencoders/data_directory/satellite_images/image_-097.9842832_+46.9299130.png']

# %%
# Directory to save processed images with 'zoom15_bilateral'
output_folder = '/content/drive/MyDrive/Autoencoders/data_directory/satellite_images_bilateral'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Process each image in the list
for i in image_list:
    # Read the image
    im = cv2.imread(i)

    # Apply bilateral blur
    im_bilateral = cv2.bilateralFilter(src=im, d=7, sigmaColor=20, sigmaSpace=200)
    for j in range(5):
        im_bilateral = cv2.bilateralFilter(src=im_bilateral, d=7, sigmaColor=20, sigmaSpace=200)


    # Extract the file name from the path
    file_name = os.path.basename(i)

    # Create a new file name with 'zoom15_bilateral' attached
    new_name = os.path.join(output_folder, file_name.replace('.png', 'zoom15_bilateral.png'))

    # Save the processed image with the new name
    cv2.imwrite(new_name, im_bilateral)

    print(f'Saved processed image as {new_name}')
# Out:
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_bilateral/image_-102.5331983_+46.0968146zoom15_bilateral.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_bilateral/image_-097.8551057_+46.9370110zoom15_bilateral.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_bilateral/image_-098.2386037_+46.9379265zoom15_bilateral.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_bilateral/image_-098.0215419_+46.9195583zoom15_bilateral.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_bilateral/image_-097.9842832_+46.9299130zoom15_bilateral.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_bilateral/image_-099.1577586_+47.9418196zoom15_bilateral.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_bilateral/image_-098.7589395_+47.9268862zoom15_bilateral.png
# Saved processed image as /content/drive/MyDrive/Autoencoders/data_directory/satellite_images_bilateral/image_